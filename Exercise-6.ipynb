# %% [markdown]
# ## TMA4215 - Exercise 6 ##
# *Hanna Heshmati Rød*

# %% [markdown]
# #### Problem 1

# %% [markdown]
# #### a)
#
# We need to find a quadrature formula of the form:
#
# $$
# \int_0^1 x f(x) \, dx \approx \sum_{i=0}^1 A_i f(x_i),
# $$
#
# where the formula is exact for all polynomials of degree 3. This means the approximation must match the exact integral for any polynomial $ f(x) $ up to degree 3.
#
# We test the formula on the basis functions $ f(x) = 1 $, $ f(x) = x $, $ f(x) = x^2 $, and $ f(x) = x^3 $. The values of these integrals are:
#
# - For $ f(x) = 1 $:
#   $$
#   \int_0^1 x \cdot 1 \, dx = \int_0^1 x \, dx = \left[ \frac{x^2}{2} \right]_0^1 = \frac{1}{2}
#   $$
#
# - For $ f(x) = x $:
#   $$
#   \int_0^1 x \cdot x \, dx = \int_0^1 x^2 \, dx = \left[ \frac{x^3}{3} \right]_0^1 = \frac{1}{3}
#   $$
#
# - For $ f(x) = x^2 $:
#   $$
#   \int_0^1 x \cdot x^2 \, dx = \int_0^1 x^3 \, dx = \left[ \frac{x^4}{4} \right]_0^1 = \frac{1}{4}
#   $$
#
# - For $ f(x) = x^3 $:
#   $$
#   \int_0^1 x \cdot x^3 \, dx = \int_0^1 x^4 \, dx = \left[ \frac{x^5}{5} \right]_0^1 = \frac{1}{5}
#   $$
#
#
# The quadrature formula is:
#
# $$
# \int_0^1 x f(x) \, dx \approx A_0 f(x_0) + A_1 f(x_1),
# $$
#
# where we want to determine the weights $ A_0, A_1 $ and the nodes $ x_0, x_1 $. For simplicity, we choose symmetric nodes:
# $$
# x_0 = \frac{1}{4}, \quad x_1 = \frac{3}{4}
# $$
#
# Now we substitute the chosen nodes into the quadrature formula. The formula must satisfy the following equations:
#
# 1. For $ f(x) = 1 $:
#    $$
#    A_0 x_0 + A_1 x_1 = \frac{1}{2}
#    $$
#
# 2. For $ f(x) = x $:
#    $$
#    A_0 x_0^2 + A_1 x_1^2 = \frac{1}{3}
#    $$
#
# 3. For $ f(x) = x^2 $:
#    $$
#    A_0 x_0^3 + A_1 x_1^3 = \frac{1}{4}
#    $$
#
# Using $ x_0 = \frac{1}{4} $ and $ x_1 = \frac{3}{4} $:
#
# 1. For $ f(x) = 1 $:
#    $$
#    A_0 \cdot \frac{1}{4} + A_1 \cdot \frac{3}{4} = \frac{1}{2}
#    $$
#
#    Simplify:
#    $$
#    \frac{A_0}{4} + \frac{3A_1}{4} = \frac{1}{2}
#    $$
#
#    Multiply through by 4:
#    $$
#    A_0 + 3A_1 = 2. \tag{1}
#    $$
#
# 2. For $ f(x) = x $:
#    $$
#    A_0 \cdot \left(\frac{1}{4}\right)^2 + A_1 \cdot \left(\frac{3}{4}\right)^2 = \frac{1}{3}
#    $$
#
#    Simplify:
#    $$
#    A_0 \cdot \frac{1}{16} + A_1 \cdot \frac{9}{16} = \frac{1}{3}
#    $$
#
#    Multiply through by 16:
#    $$
#    A_0 + 9A_1 = \frac{16}{3}. \tag{2}
#    $$
#
# 3. For $ f(x) = x^2 $:
#    $$
#    A_0 \cdot \left(\frac{1}{4}\right)^3 + A_1 \cdot \left(\frac{3}{4}\right)^3 = \frac{1}{4}
#    $$
#
#    Simplify:
#    $$
#    A_0 \cdot \frac{1}{64} + A_1 \cdot \frac{27}{64} = \frac{1}{4}
#    $$
#
#    Multiply by 64:
#    $$
#    A_0 + 27A_1 = 16. \tag{3}
#    $$
#
# The system of equations is:
#
# 1. $ A_0 + 3A_1 = 2 $
# 2. $ A_0 + 9A_1 = \frac{16}{3} $
# 3. $ A_0 + 27A_1 = 16 $
#
# From equation (1):
# $$
# A_0 = 2 - 3A_1 \tag{4}
# $$
#
# Substitute $ A_0 = 2 - 3A_1 $ into equations (2) and (3) to solve for $ A_1 $. Then back-substitute to find $ A_0 $.
#
# Hence, the weights are:
# $$
# A_0 = \frac{8}{15}, \quad A_1 = \frac{4}{15}
# $$
#
# Therefore, the final quadrature formula is:
# $$
# \int_0^1 x f(x) \, dx \approx \frac{8}{15} f\left(\frac{1}{4}\right) + \frac{4}{15} f\left(\frac{3}{4}\right)
# $$

# %% [markdown]
# #### b)
#
# Now we want to use this formula to approximate the intergal
#
# $$
# I = \int_0^1 x \sin(x) \, dx
# $$
#
# Let $ f(x) = \sin(x) $. Using the formula:
#
# $$
# I \approx \frac{8}{15} \sin\left(\frac{1}{4}\right) + \frac{4}{15} \sin\left(\frac{3}{4}\right)
# $$
#
#
# We have
#
# $$
# \sin\left(\frac{1}{4}\right) \approx 0.2474
# $$
#
# and
#
# $$
# \sin\left(\frac{3}{4}\right) \approx 0.6816
# $$
#
# Using this we get
#
# $$
# I \approx \frac{8}{15} \cdot 0.2474 + \frac{4}{15} \cdot 0.6816
# $$
#
# Simplify:
#
# $$
# I \approx \frac{8 \cdot 0.2474 + 4 \cdot 0.6816}{15} = \frac{1.9792 + 2.7264}{15} = \frac{4.7056}{15}
# $$
#
# Thus:
#
# $$
# I \approx 0.3137.
# $$
#
# We calculate the exact value of $ \int_0^1 x \sin(x) \, dx $ (for comparison) using integration by parts.
#
# Let:
# $$
# u = x, \quad dv = \sin(x) \, dx.
# $$
#
# Then:
# $$
# du = dx, \quad v = -\cos(x).
# $$
#
# Using the formula $ \int u \, dv = uv - \int v \, du $:
#
# $$
# \int_0^1 x \sin(x) \, dx = \left[ -x \cos(x) \right]_0^1 + \int_0^1 \cos(x) \, dx.
# $$
#
# We evaluate each of the terems separately:
#
# $$
# \left[ -x \cos(x) \right]_0^1 = \left( -1 \cdot \cos(1) \right) - \left( 0 \cdot \cos(0) \right) = -\cos(1).
# $$
#
# $$
# \int_0^1 \cos(x) \, dx = \sin(x) \Big|_0^1 = \sin(1) - \sin(0).
# $$
#
# Since $ \sin(0) = 0 $, this simplifies to:
# $$
# \int_0^1 \cos(x) \, dx = \sin(1).
# $$
#
# Now piecing back together:
#
# $$
# \int_0^1 x \sin(x) \, dx = -\cos(1) + \sin(1).
# $$
#
# Using approximate values $ \cos(1) \approx 0.5403 $ and $ \sin(1) \approx 0.8415 $:
#
# $$
# \int_0^1 x \sin(x) \, dx \approx -0.5403 + 0.8415 = 0.3012.
# $$
#
#
# The error is given by the difference between the exact value and the approximation:
#
# $$
# E = 0.3012 - 0.3137 = -0.0125.
# $$
